# %% [markdown]
# <a href="https://colab.research.google.com/github/mamoonmasud/graph_community/blob/main/LGNN_Semi_supervised.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
! pip install dgl-cu111 -f https://data.dgl.ai/wheels/repo.html
# Out:
# Looking in links: https://data.dgl.ai/wheels/repo.html
# Collecting dgl-cu111
#   Downloading https://data.dgl.ai/wheels/dgl_cu111-0.7.2-cp37-cp37m-manylinux1_x86_64.whl (165.0 MB)
#      |████████████████████████████████| 165.0 MB 49 kB/s
# Requirement already satisfied: networkx>=2.1 in /usr/local/lib/python3.7/dist-packages (from dgl-cu111) (2.6.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from dgl-cu111) (2.23.0)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from dgl-cu111) (1.19.5)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from dgl-cu111) (1.4.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->dgl-cu111) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->dgl-cu111) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->dgl-cu111) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->dgl-cu111) (2.10)
# Installing collected packages: dgl-cu111
# Successfully installed dgl-cu111-0.7.2

# %%
import dgl
import dgl.function as fn
from dgl import DGLGraph
from dgl.data import citation_graph as citegrh
from dgl.data import DGLDataset
# pytorch
import torch as th
import torch.nn as nn
import torch.nn.functional as F
import pandas as pd
# other
import time
import numpy as np
import random as rng
import scipy.sparse as ss
import networkx as nx
import pickle
from sklearn import metrics as skmetrics
from scipy import sparse as sp
from sklearn.metrics import accuracy_score as acc
from math import log

# %%
from google.colab import files
def upload_files():
  from google.colab import files
  uploaded = files.upload()
  for k, v in uploaded.items():
    open(k, 'wb').write(v)
  return list(uploaded.keys())

upload_files()
#Upload LGNN.py, performance.py and SparseMax.py
# Out:
#      <input type="file" id="files-628a4bb2-b5ed-4f78-a36a-7d81a2d84ff4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-628a4bb2-b5ed-4f78-a36a-7d81a2d84ff4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving LGNN.py to LGNN.py
# Saving performance.py to performance.py
# Saving Sparsemax.py to Sparsemax.py
# ['LGNN.py', 'performance.py', 'Sparsemax.py']

# %%
import LGNN
#from LGNN import LGNN_Net
import importlib
importlib.reload(LGNN)
# Out:
# <module 'LGNN' from '/content/LGNN.py'>

# %%
# LGNN Definition


class LGNN_Net(nn.Module):
    """This is a whole LGNN"""

    def __init__(
        self, g, in_feats, hidden_size, hidden_layers, out_feats, dropout, batchnorm, lg, radius
    ):
        super(LGNN_Net, self).__init__()
        self.g = g
        self.lg = lg
        in_feats = [in_feats] + [hidden_size] * hidden_layers
        self.module_list = nn.ModuleList(
            [LGNNModule(m, n, radius, batchnorm) for m, n in zip(in_feats[:-1], in_feats[1:])]
        )
        self.linear = nn.Linear(in_feats[-1], out_feats)
        self.dropout = nn.Dropout(dropout)

        self.pmpd = self.g.edges()[0]

        # compute the degrees
        self.deg_g = self.g.in_degrees().float().unsqueeze(1)
        self.deg_lg = self.lg.in_degrees().float().unsqueeze(1)

    def forward(self, features):
        (h, lg_h) = features
        for i, module in enumerate(self.module_list):
            if i == len(self.module_list) - 1:
                h = module(
                    self.g, self.lg, h, lg_h, self.deg_g, self.deg_lg, self.pmpd, last=True
                )  # the last pass should only return h, otherwhise we get a memory leak
                h = self.dropout(h)
            else:
                h, lg_h = module(self.g, self.lg, h, lg_h, self.deg_g, self.deg_lg, self.pmpd)
                h = self.dropout(h)
                lg_h = self.dropout(lg_h)
        h = self.linear(h)
        h = F.log_softmax(h, 1)
        return h

# %%
class LGNNModule(nn.Module):
    """This is a graph network block of LGNN"""

    def __init__(self, in_feats, out_feats, radius, batchnorm):
        super().__init__()
        self.out_feats = out_feats
        self.radius = radius

        new_linear = lambda: nn.Linear(in_feats, out_feats)
        new_linear_list = lambda: nn.ModuleList([new_linear() for i in range(radius)])

        self.theta_x, self.theta_deg, self.theta_y = new_linear(), new_linear(), new_linear()
        self.theta_list = new_linear_list()

        self.gamma_y, self.gamma_deg, self.gamma_x = new_linear(), new_linear(), new_linear()
        self.gamma_list = new_linear_list()

        self.batchnorm = batchnorm
        self.bn_x = nn.BatchNorm1d(out_feats)
        self.bn_y = nn.BatchNorm1d(out_feats)

    def aggregate(self, a_graph, z):
        z_list = []
        a_graph.ndata['z'] = z
        # ntid = a_graph.get_ntype_id(None)
        #a_graph._set_n_repr(ntid, u= z, data = {"z": z})
        a_graph.update_all(fn.copy_src(src="z", out="m"), fn.sum(msg="m", out="z"))
        z_list.append(a_graph.ndata["z"])
        for i in range(self.radius - 1):
            for j in range(2 ** i):
                a_graph.update_all(fn.copy_src(src="z", out="m"), fn.sum(msg="m", out="z"))
            z_list.append(a_graph.ndata["z"])
        return z_list
        

    def forward(self, g, lg, x, y, deg_g, deg_lg, pm_pd, last=False):
        pmpd_x = F.embedding(pm_pd, x)

        sum_x = sum(theta(z) for theta, z in zip(self.theta_list, self.aggregate(g, x)))

        g.edata["y"] = y
        g.update_all(fn.copy_edge(edge="y", out="m"), fn.sum("m", "pmpd_y"))
        pmpd_y = g.ndata.pop("pmpd_y")

        x = self.theta_x(x) + self.theta_deg(deg_g * x) + sum_x + self.theta_y(pmpd_y)
        n = self.out_feats // 2
        x = th.cat([x[:, :n], F.relu(x[:, n:])], 1)
        if self.batchnorm:
            x = self.bn_x(x)

        if last:
            return x  # do not compute the rest of the lgnn part to avoid memory leak

        sum_y = sum(gamma(z) for gamma, z in zip(self.gamma_list, self.aggregate(lg, y)))

        y = self.gamma_y(y) + self.gamma_deg(deg_lg * y) + sum_y + self.gamma_x(pmpd_x)
        y = th.cat([y[:, :n], F.relu(y[:, n:])], 1)
        if self.batchnorm:
            y = self.bn_y(y)

        return x, y

# %% [markdown]
# ## Loading the dataset

# %%
#Loading CORA
data = citegrh.load_cora()

g = data[0]
num_class = data.num_classes

features = g.ndata['feat']

train_mask = g.ndata['train_mask']
val_mask = g.ndata['val_mask']
test_mask = g.ndata['test_mask']
labels = g.ndata['label']

# add self loop
#g.remove_edges_from(nx.selfloop_edges(g))
g  = dgl.remove_self_loop(g)
#g = DGLGraph(g)
#g.add_edges(g.nodes(), g.nodes())

comb_mask = th.zeros(len(train_mask), dtype=torch.bool)

for i in range(len(comb_mask)):
    if test_mask[i] or train_mask[i] or val_mask[i]:
        comb_mask[i] = True

lg_feat = np.vstack([features[e[0],:]*features[e[1],:] for e in data.graph.edges])
# Out:
#   NumNodes: 2708
#   NumEdges: 10556
#   NumFeats: 1433
#   NumClasses: 7
#   NumTrainingSamples: 140
#   NumValidationSamples: 500
#   NumTestSamples: 1000
# Done loading data from cached files.
# /usr/local/lib/python3.7/dist-packages/dgl/data/utils.py:286: UserWarning: Property dataset.graph will be deprecated, please use dataset[0] instead.
#   warnings.warn('Property {} will be deprecated, please use {} instead.'.format(old, new))

# %%
# Generating a dgl graph from the given csv files of github dataset at: http://snap.stanford.edu/data/github-social.html

# class GitHubDataset(DGLDataset):
#     def __init__(self):
#         super().__init__(name='github_dataset')

#     def process(self):
#         nodes_data = pd.read_csv('drive/MyDrive/CSCE689/data_git/papers.csv')
#         edges_data = pd.read_csv('drive/MyDrive/CSCE689/data_git/git_edges.csv')
#         node_target = pd.read_csv('drive/MyDrive/CSCE689/data_git/musae_git_target.csv')
#         node_features = torch.from_numpy(nodes_data.to_numpy())
#         node_labels = torch.from_numpy(node_target["ml_target"].astype('category').cat.codes.to_numpy())
#         #edge_features = torch.from_numpy(edges_data['Weight'].to_numpy())
#         edges_src = torch.from_numpy(edges_data['source'].to_numpy())
#         edges_dst = torch.from_numpy(edges_data['target'].to_numpy())

#         self.graph = dgl.graph((edges_src, edges_dst), num_nodes=nodes_data.shape[0])
#         self.graph.ndata['feat'] = node_features
#         self.graph.ndata['label'] = node_labels
#         #self.graph.edata['weight'] = edge_features

#         # If your dataset is a node classification dataset, you will need to assign
#         # masks indicating whether a node belongs to training, validation, and test set.
#         n_nodes = nodes_data.shape[0]
#         n_train = int(n_nodes * 0.6)
#         n_val = int(n_nodes * 0.2)
#         train_mask = torch.zeros(n_nodes, dtype=torch.bool)
#         val_mask = torch.zeros(n_nodes, dtype=torch.bool)
#         test_mask = torch.zeros(n_nodes, dtype=torch.bool)
#         train_mask[:n_train] = True
#         val_mask[n_train:n_train + n_val] = True
#         test_mask[n_train + n_val:] = True
#         self.graph.ndata['train_mask'] = train_mask
#         self.graph.ndata['val_mask'] = val_mask
#         self.graph.ndata['test_mask'] = test_mask

#     def __getitem__(self, i):
#         return self.graph

#     def __len__(self):
#         return 1

# dataset = GitHubDataset()
# graph = dataset[0]

# %%
# num_class = 2

# features = graph.ndata['feat']

# train_mask = graph.ndata['train_mask']
# val_mask = graph.ndata['val_mask']
# test_mask = graph.ndata['test_mask']
# labels = graph.ndata['label']

# # add self loop
# #g.remove_edges_from(nx.selfloop_edges(g))
# graph = dgl.remove_self_loop(graph)
# #g = DGLGraph(g)
# graph.add_edges(graph.nodes(), graph.nodes())

# comb_mask = torch.zeros(len(train_mask), dtype=torch.bool)

# for i in range(len(comb_mask)):
#     if test_mask[i] or train_mask[i] or val_mask[i]:
#         comb_mask[i] = True

# %%
graph = g
lg = graph.line_graph(backtracking=False)

# %%
print('The graph has %d nodes.' % graph.number_of_nodes())
print('The graph has %d edges.' % graph.number_of_edges())
# Out:
# The graph has 2708 nodes.
# The graph has 10556 edges.

# %%
# Training set selection

percentage_train = 0.1
percentage_val = 0.1

with open("drive/MyDrive/CSCE689/data/cora_permutation1.pickle","rb") as f:
    perm1 = pickle.load(f)
mask_train = np.zeros(g.number_of_nodes())
mask_val = np.zeros(g.number_of_nodes())

i_train = int(percentage_train*g.number_of_nodes())
i_val = i_train + int(percentage_val*g.number_of_nodes())
mask_train[perm1[range(0,i_train)]] = 1
mask_val[perm1[range(i_train,i_val)]] = 1
mask_train = th.BoolTensor(mask_train)
mask_val = th.BoolTensor(mask_val)

# %%
# Training Block

# create the model
degrees = False
if degrees:
    # use degree as the input feature
    # compute the degrees
    g_feat = g.in_degrees().float().unsqueeze(1)
    lg_feat = lg.in_degrees().float().unsqueeze(1)  
else:
    # use astracts as input feature
    g_feat = features
    lg_feat = th.FloatTensor(np.vstack([features[e[0],:] for e in data.graph.edges]))
    
net = LGNN_Net(g=g,in_feats=g_feat.shape[1],hidden_size=21,hidden_layers=2,out_feats=7,
               dropout=0.1,batchnorm=False,lg=lg,radius=2)

# define the optimizer
optimizer = th.optim.Adam(net.parameters(), lr=0.01, weight_decay=0.1)

all_logits = []
all_losses = []
all_losses_val = []

# train
for epoch in range(1000):

    # Compute loss for test nodes (only for validation, not used by optimizer)
    net.eval()
    prediction = F.log_softmax(net((g_feat, lg_feat)),1)
    val_loss = F.nll_loss(prediction.detach()[mask_val], labels[mask_val])
    all_losses_val.append(val_loss.item())
    val_acc = acc(labels[mask_val],prediction.detach()[mask_val].numpy().argmax(axis=1))
    net.train()

    logits = net((g_feat, lg_feat))
    
    # Save logits for visualization later
    all_logits.append(logits.detach())
    logp = F.log_softmax(logits, 1)

    # Compute loss for train nodes
    loss = F.nll_loss(logp[mask_train], labels[mask_train])
    all_losses.append(loss.detach().item())

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    print('Epoch %d | Loss: %.4f | Total: %.4f | Acc: %.4f' % (epoch, loss.item(), val_loss.item(),val_acc))
# Out:
# /usr/local/lib/python3.7/dist-packages/dgl/data/utils.py:286: UserWarning: Property dataset.graph will be deprecated, please use dataset[0] instead.
#   warnings.warn('Property {} will be deprecated, please use {} instead.'.format(old, new))
# Epoch 0 | Loss: 5.1646 | Total: 5.1125 | Acc: 0.1815
# Epoch 1 | Loss: 7.8874 | Total: 7.9574 | Acc: 0.1000
# Epoch 2 | Loss: 10.4513 | Total: 13.2303 | Acc: 0.2259
# Epoch 3 | Loss: 5.6851 | Total: 11.9521 | Acc: 0.3519
# Epoch 4 | Loss: 4.6439 | Total: 10.2513 | Acc: 0.4370
# Epoch 5 | Loss: 4.6245 | Total: 9.2199 | Acc: 0.4593
# Epoch 6 | Loss: 3.1084 | Total: 6.8866 | Acc: 0.5556
# Epoch 7 | Loss: 2.2299 | Total: 5.2760 | Acc: 0.6481
# Epoch 8 | Loss: 4.6065 | Total: 5.6182 | Acc: 0.5741
# Epoch 9 | Loss: 2.5580 | Total: 5.6917 | Acc: 0.5407
# Epoch 10 | Loss: 2.2571 | Total: 6.3967 | Acc: 0.5519
# Epoch 11 | Loss: 1.9786 | Total: 6.6983 | Acc: 0.6000
# Epoch 12 | Loss: 1.5839 | Total: 6.9167 | Acc: 0.6519
# Epoch 13 | Loss: 1.6796 | Total: 7.0009 | Acc: 0.7000
# Epoch 14 | Loss: 1.6735 | Total: 6.8652 | Acc: 0.7296
# Epoch 15 | Loss: 1.6412 | Total: 6.4899 | Acc: 0.7519
# Epoch 16 | Loss: 1.4769 | Total: 6.1346 | Acc: 0.7370
# Epoch 17 | Loss: 1.6275 | Total: 6.0101 | Acc: 0.6963
# Epoch 18 | Loss: 1.3094 | Total: 6.2906 | Acc: 0.7185
# Epoch 19 | Loss: 1.8272 | Total: 6.6330 | Acc: 0.7333
# Epoch 985 | Loss: 0.4860 | Total: 2.7573 | Acc: 0.7444
# Epoch 986 | Loss: 0.5018 | Total: 2.8248 | Acc: 0.7296
# Epoch 987 | Loss: 0.5055 | Total: 2.9330 | Acc: 0.7333
# Epoch 988 | Loss: 0.4817 | Total: 2.9081 | Acc: 0.7370
# Epoch 989 | Loss: 0.4970 | Total: 2.8779 | Acc: 0.7407
# Epoch 990 | Loss: 0.4909 | Total: 2.8894 | Acc: 0.7556
# Epoch 991 | Loss: 0.5035 | Total: 2.9737 | Acc: 0.7481
# Epoch 992 | Loss: 0.4781 | Total: 2.8694 | Acc: 0.7222
# Epoch 993 | Loss: 0.4600 | Total: 2.7623 | Acc: 0.7407
# Epoch 994 | Loss: 0.5187 | Total: 2.6676 | Acc: 0.7296
# Epoch 995 | Loss: 0.4805 | Total: 2.7039 | Acc: 0.7519
# Epoch 996 | Loss: 0.4705 | Total: 2.9161 | Acc: 0.7407
# Epoch 997 | Loss: 0.4979 | Total: 3.0360 | Acc: 0.7370
# Epoch 998 | Loss: 0.4946 | Total: 2.9315 | Acc: 0.7407
# Epoch 999 | Loss: 0.4920 | Total: 2.9142 | Acc: 0.7593

# %%
import time

# create the model
degrees = False
if degrees:
    # use degree as the input feature
    # compute the degrees
    g_feat = g.in_degrees().float().unsqueeze(1)
    lg_feat = lg.in_degrees().float().unsqueeze(1)  
else:
    # use astracts as input feature
    g_feat = th.FloatTensor(data.features)
    lg_feat = th.FloatTensor(np.vstack([data.features[e[0],:] for e in data.graph.edges]))
features = (g_feat,lg_feat)
    
net = LGNN_Net(g=g,in_feats=g_feat.shape[1],hidden_size=21,hidden_layers=2,out_feats=7,
               dropout=0.1,batchnorm=False,lg=lg,radius=2)
#print(net)

optimizer = th.optim.Adam(net.parameters(), lr=1e-2, weight_decay=1e-2)
net.train() # Set to training mode (use dropout)

dur = []
loss_ev = []
current_best = 0 #arbitrarily high
current_best_epoch = 0
current_best_params = None
no_improvement_for = 0

for epoch in range(10000):
    if epoch >=3:
        t0 = time.time()

    # Compute loss for test nodes (only for validation, not used by optimizer)
    net.eval()
    prediction = net(features)
    train_rand=pf.rand_score(labels[mask_train].numpy(),np.argmax(prediction[mask_train].detach().numpy(), axis=1))
    validation_rand=pf.rand_score(labels[mask_val].numpy(),np.argmax(prediction[mask_val].detach().numpy(), axis=1))
    if train_rand>current_best:
        current_best = train_rand
        current_best_epoch = epoch
        current_best_params = copy.deepcopy(net.state_dict())
        no_improvement_for = 0
    else: no_improvement_for += 1
    
    if no_improvement_for>100:
        break
    
    net.train()

    # Compute loss for train nodes
    logits = net(features)

    loss = loss_function.approximate_loss(logits,mask_train,nclasses=7)
    loss_ev.append(loss.detach().item())

    #loss = F.nll_loss(logits[mask_train], labels[mask_train])
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if epoch >=3:
        dur.append(time.time() - t0)
        print(f"Epoch {epoch:05d} | Loss {loss.item():.4f} | Train.Rand {train_rand:.4f} | Valid.Rand {validation_rand:.4f} | Time(s) {np.mean(dur):.4f}")
    else:
        print(f"Epoch {epoch:05d} | Loss {loss.item():.4f} | Train.Rand {train_rand:.4f} | Valid.Rand {validation_rand:.4f} | Time(s) unknown")
        
net.load_state_dict(current_best_params)
# Out:
# /usr/local/lib/python3.7/dist-packages/dgl/data/utils.py:286: UserWarning: Property dataset.feat will be deprecated, please use g.ndata['feat'] instead.
#   warnings.warn('Property {} will be deprecated, please use {} instead.'.format(old, new))
# /usr/local/lib/python3.7/dist-packages/dgl/data/utils.py:286: UserWarning: Property dataset.graph will be deprecated, please use dataset[0] instead.
#   warnings.warn('Property {} will be deprecated, please use {} instead.'.format(old, new))
# Epoch 00000 | Loss 2.0113 | Train.Rand 0.0011 | Valid.Rand 0.0147 | Time(s) unknown
# Epoch 00001 | Loss 6.0721 | Train.Rand 0.0530 | Valid.Rand 0.0678 | Time(s) unknown
# Epoch 00002 | Loss 6.3258 | Train.Rand 0.0983 | Valid.Rand 0.0774 | Time(s) unknown
# Epoch 00003 | Loss 3.9676 | Train.Rand 0.2126 | Valid.Rand 0.1921 | Time(s) 2.2646
# Epoch 00004 | Loss 3.5805 | Train.Rand 0.3132 | Valid.Rand 0.2953 | Time(s) 2.2639
# Epoch 00005 | Loss 4.4708 | Train.Rand 0.2647 | Valid.Rand 0.2336 | Time(s) 2.3178
# Epoch 00006 | Loss 2.7750 | Train.Rand 0.2691 | Valid.Rand 0.2411 | Time(s) 2.2671
# Epoch 00007 | Loss 2.8214 | Train.Rand 0.3182 | Valid.Rand 0.2711 | Time(s) 2.2923
# Epoch 00008 | Loss 1.9709 | Train.Rand 0.3749 | Valid.Rand 0.2994 | Time(s) 2.2583
# Epoch 00009 | Loss 1.7102 | Train.Rand 0.4275 | Valid.Rand 0.3688 | Time(s) 2.2823
# Epoch 00010 | Loss 1.4931 | Train.Rand 0.4070 | Valid.Rand 0.3492 | Time(s) 2.2587
# Epoch 00011 | Loss 1.5893 | Train.Rand 0.4048 | Valid.Rand 0.3303 | Time(s) 2.2369
# Epoch 00012 | Loss 1.5936 | Train.Rand 0.4409 | Valid.Rand 0.3888 | Time(s) 2.2376
# Epoch 00013 | Loss 1.2417 | Train.Rand 0.5262 | Valid.Rand 0.4193 | Time(s) 2.2295
# Epoch 00014 | Loss 1.4129 | Train.Rand 0.5376 | Valid.Rand 0.4298 | Time(s) 2.2339
# Epoch 00015 | Loss 0.9395 | Train.Rand 0.5541 | Valid.Rand 0.4403 | Time(s) 2.2250
# Epoch 00016 | Loss 1.0359 | Train.Rand 0.5838 | Valid.Rand 0.4178 | Time(s) 2.2150
# Epoch 00017 | Loss 1.0915 | Train.Rand 0.5987 | Valid.Rand 0.4309 | Time(s) 2.2100
# Epoch 00018 | Loss 1.0185 | Train.Rand 0.6500 | Valid.Rand 0.4645 | Time(s) 2.2025
# Epoch 00019 | Loss 1.0459 | Train.Rand 0.6817 | Valid.Rand 0.5061 | Time(s) 2.1952
# Epoch 00020 | Loss 0.9701 | Train.Rand 0.6801 | Valid.Rand 0.4955 | Time(s) 2.2078
# Epoch 00021 | Loss 0.9352 | Train.Rand 0.6607 | Valid.Rand 0.4882 | Time(s) 2.2153
# Epoch 00022 | Loss 1.1700 | Train.Rand 0.6291 | Valid.Rand 0.4741 | Time(s) 2.2071
# Epoch 00023 | Loss 0.8572 | Train.Rand 0.6351 | Valid.Rand 0.4784 | Time(s) 2.2070
# Epoch 00024 | Loss 0.7536 | Train.Rand 0.6276 | Valid.Rand 0.5109 | Time(s) 2.2028
# Epoch 00025 | Loss 0.7823 | Train.Rand 0.6116 | Valid.Rand 0.4945 | Time(s) 2.2101
# Epoch 00026 | Loss 0.8415 | Train.Rand 0.6456 | Valid.Rand 0.4661 | Time(s) 2.2062
# Epoch 00027 | Loss 0.8626 | Train.Rand 0.6630 | Valid.Rand 0.4841 | Time(s) 2.2003
# Epoch 00028 | Loss 0.6927 | Train.Rand 0.6717 | Valid.Rand 0.4962 | Time(s) 2.1959
# Epoch 00029 | Loss 0.6742 | Train.Rand 0.7150 | Valid.Rand 0.4722 | Time(s) 2.2001
# Epoch 00030 | Loss 0.7001 | Train.Rand 0.7073 | Valid.Rand 0.5313 | Time(s) 2.1979
# Epoch 00031 | Loss 0.6918 | Train.Rand 0.6664 | Valid.Rand 0.5172 | Time(s) 2.1933
# Epoch 00032 | Loss 0.6958 | Train.Rand 0.6540 | Valid.Rand 0.4948 | Time(s) 2.1897
# Epoch 00033 | Loss 0.6502 | Train.Rand 0.6659 | Valid.Rand 0.4921 | Time(s) 2.1882
# Epoch 00034 | Loss 0.5938 | Train.Rand 0.6653 | Valid.Rand 0.5101 | Time(s) 2.1953
# Epoch 00035 | Loss 0.5984 | Train.Rand 0.6882 | Valid.Rand 0.5254 | Time(s) 2.1957
# Epoch 00036 | Loss 0.5900 | Train.Rand 0.7406 | Valid.Rand 0.4864 | Time(s) 2.1958
# Epoch 00037 | Loss 0.5713 | Train.Rand 0.7198 | Valid.Rand 0.4510 | Time(s) 2.1913
# Epoch 00038 | Loss 0.5491 | Train.Rand 0.7339 | Valid.Rand 0.4557 | Time(s) 2.1912
# Epoch 00039 | Loss 0.5981 | Train.Rand 0.7436 | Valid.Rand 0.4557 | Time(s) 2.1894
# Epoch 00040 | Loss 0.5505 | Train.Rand 0.7683 | Valid.Rand 0.4603 | Time(s) 2.1863
# Epoch 00041 | Loss 0.4526 | Train.Rand 0.7476 | Valid.Rand 0.5052 | Time(s) 2.1877
# Epoch 00042 | Loss 0.4943 | Train.Rand 0.7370 | Valid.Rand 0.5134 | Time(s) 2.1886
# Epoch 00043 | Loss 0.4700 | Train.Rand 0.7144 | Valid.Rand 0.5036 | Time(s) 2.1871
# Epoch 00044 | Loss 0.4532 | Train.Rand 0.7365 | Valid.Rand 0.5044 | Time(s) 2.1911
# Epoch 00045 | Loss 0.4664 | Train.Rand 0.7410 | Valid.Rand 0.5158 | Time(s) 2.1893
# Epoch 00046 | Loss 0.4120 | Train.Rand 0.7908 | Valid.Rand 0.5117 | Time(s) 2.1888
# Epoch 00047 | Loss 0.4834 | Train.Rand 0.8062 | Valid.Rand 0.5119 | Time(s) 2.1889
# Epoch 00048 | Loss 0.4109 | Train.Rand 0.8020 | Valid.Rand 0.5167 | Time(s) 2.1897
# Epoch 00049 | Loss 0.4397 | Train.Rand 0.8211 | Valid.Rand 0.5149 | Time(s) 2.1887
# Epoch 00050 | Loss 0.4301 | Train.Rand 0.8216 | Valid.Rand 0.4961 | Time(s) 2.1868
# Epoch 00051 | Loss 0.4510 | Train.Rand 0.8295 | Valid.Rand 0.4963 | Time(s) 2.1860
# Epoch 00052 | Loss 0.3731 | Train.Rand 0.8030 | Valid.Rand 0.5081 | Time(s) 2.1861
# Epoch 00053 | Loss 0.4252 | Train.Rand 0.7914 | Valid.Rand 0.5085 | Time(s) 2.1886
# Epoch 00054 | Loss 0.4058 | Train.Rand 0.8374 | Valid.Rand 0.4830 | Time(s) 2.1885
# Epoch 00055 | Loss 0.3631 | Train.Rand 0.8275 | Valid.Rand 0.4928 | Time(s) 2.1857
# Epoch 00056 | Loss 0.3664 | Train.Rand 0.8379 | Valid.Rand 0.4935 | Time(s) 2.1838
# Epoch 00057 | Loss 0.3794 | Train.Rand 0.8379 | Valid.Rand 0.5006 | Time(s) 2.1834
# Epoch 00058 | Loss 0.3433 | Train.Rand 0.8379 | Valid.Rand 0.5127 | Time(s) 2.1845
# Epoch 00059 | Loss 0.3569 | Train.Rand 0.8391 | Valid.Rand 0.5115 | Time(s) 2.1876
# Epoch 00060 | Loss 0.3444 | Train.Rand 0.8328 | Valid.Rand 0.5115 | Time(s) 2.1854
# Epoch 00061 | Loss 0.3259 | Train.Rand 0.8245 | Valid.Rand 0.5099 | Time(s) 2.1869
# Epoch 00062 | Loss 0.4027 | Train.Rand 0.8307 | Valid.Rand 0.5327 | Time(s) 2.1865
# Epoch 00063 | Loss 0.3201 | Train.Rand 0.8272 | Valid.Rand 0.5264 | Time(s) 2.1850
# Epoch 00064 | Loss 0.3788 | Train.Rand 0.8459 | Valid.Rand 0.5264 | Time(s) 2.1855
# Epoch 00065 | Loss 0.2992 | Train.Rand 0.8459 | Valid.Rand 0.4929 | Time(s) 2.1879
# Epoch 00066 | Loss 0.3029 | Train.Rand 0.8459 | Valid.Rand 0.4991 | Time(s) 2.1866
# Epoch 00067 | Loss 0.2939 | Train.Rand 0.8397 | Valid.Rand 0.5064 | Time(s) 2.1850
# Epoch 00068 | Loss 0.2911 | Train.Rand 0.8397 | Valid.Rand 0.5015 | Time(s) 2.1856
# Epoch 00069 | Loss 0.2879 | Train.Rand 0.8571 | Valid.Rand 0.4948 | Time(s) 2.1857
# Epoch 00070 | Loss 0.2767 | Train.Rand 0.8536 | Valid.Rand 0.5030 | Time(s) 2.1871
# Epoch 00071 | Loss 0.3034 | Train.Rand 0.8640 | Valid.Rand 0.5266 | Time(s) 2.1853
# Epoch 00072 | Loss 0.2630 | Train.Rand 0.8640 | Valid.Rand 0.5260 | Time(s) 2.1836
# Epoch 00073 | Loss 0.2765 | Train.Rand 0.8577 | Valid.Rand 0.5019 | Time(s) 2.1821
# Epoch 00074 | Loss 0.3008 | Train.Rand 0.8507 | Valid.Rand 0.5023 | Time(s) 2.1822
# Epoch 00075 | Loss 0.2790 | Train.Rand 0.8473 | Valid.Rand 0.5022 | Time(s) 2.1826
# Epoch 00076 | Loss 0.2630 | Train.Rand 0.8606 | Valid.Rand 0.4936 | Time(s) 2.1851
# Epoch 00077 | Loss 0.2698 | Train.Rand 0.8676 | Valid.Rand 0.4886 | Time(s) 2.1857
# Epoch 00078 | Loss 0.3114 | Train.Rand 0.8676 | Valid.Rand 0.5053 | Time(s) 2.1852
# Epoch 00079 | Loss 0.2683 | Train.Rand 0.8576 | Valid.Rand 0.4882 | Time(s) 2.1837
# Epoch 00080 | Loss 0.3253 | Train.Rand 0.8410 | Valid.Rand 0.5107 | Time(s) 2.1835
# Epoch 00081 | Loss 0.3614 | Train.Rand 0.8379 | Valid.Rand 0.5090 | Time(s) 2.1834
# Epoch 00082 | Loss 0.3282 | Train.Rand 0.8493 | Valid.Rand 0.5049 | Time(s) 2.1851
# Epoch 00083 | Loss 0.2992 | Train.Rand 0.8358 | Valid.Rand 0.5355 | Time(s) 2.1836
# Epoch 00084 | Loss 0.2675 | Train.Rand 0.8514 | Valid.Rand 0.5214 | Time(s) 2.1833
# Epoch 00085 | Loss 0.2676 | Train.Rand 0.8514 | Valid.Rand 0.5048 | Time(s) 2.1841
# Epoch 00086 | Loss 0.2791 | Train.Rand 0.8674 | Valid.Rand 0.5077 | Time(s) 2.1868
# Epoch 00087 | Loss 0.2549 | Train.Rand 0.8647 | Valid.Rand 0.5068 | Time(s) 2.1880
# Epoch 00088 | Loss 0.2478 | Train.Rand 0.8718 | Valid.Rand 0.5083 | Time(s) 2.1878
# Epoch 00089 | Loss 0.2411 | Train.Rand 0.8742 | Valid.Rand 0.5060 | Time(s) 2.1893
# Epoch 00090 | Loss 0.2753 | Train.Rand 0.8742 | Valid.Rand 0.5071 | Time(s) 2.1893
# Epoch 00091 | Loss 0.2718 | Train.Rand 0.8467 | Valid.Rand 0.5010 | Time(s) 2.1881
# Epoch 00092 | Loss 0.2394 | Train.Rand 0.8678 | Valid.Rand 0.5216 | Time(s) 2.1888
# Epoch 00093 | Loss 0.2628 | Train.Rand 0.8742 | Valid.Rand 0.5015 | Time(s) 2.1905
# Epoch 00094 | Loss 0.2169 | Train.Rand 0.8862 | Valid.Rand 0.5098 | Time(s) 2.1927
# Epoch 00095 | Loss 0.2479 | Train.Rand 0.8866 | Valid.Rand 0.4928 | Time(s) 2.1921
# Epoch 00096 | Loss 0.2381 | Train.Rand 0.8902 | Valid.Rand 0.4859 | Time(s) 2.1906
# Epoch 00097 | Loss 0.2174 | Train.Rand 0.8810 | Valid.Rand 0.5069 | Time(s) 2.1915
# Epoch 00098 | Loss 0.2441 | Train.Rand 0.8810 | Valid.Rand 0.4847 | Time(s) 2.1921
# Epoch 00099 | Loss 0.2597 | Train.Rand 0.8862 | Valid.Rand 0.4737 | Time(s) 2.1917
# Epoch 00100 | Loss 0.2055 | Train.Rand 0.9011 | Valid.Rand 0.4986 | Time(s) 2.1908
# Epoch 00101 | Loss 0.2191 | Train.Rand 0.9011 | Valid.Rand 0.5093 | Time(s) 2.1917
# Epoch 00102 | Loss 0.2105 | Train.Rand 0.9011 | Valid.Rand 0.5088 | Time(s) 2.1925
# Epoch 00103 | Loss 0.2198 | Train.Rand 0.8902 | Valid.Rand 0.5176 | Time(s) 2.1927
# Epoch 00104 | Loss 0.2152 | Train.Rand 0.8862 | Valid.Rand 0.5142 | Time(s) 2.1928
# Epoch 00105 | Loss 0.2651 | Train.Rand 0.8742 | Valid.Rand 0.5336 | Time(s) 2.1939
# Epoch 00106 | Loss 0.2183 | Train.Rand 0.8742 | Valid.Rand 0.5280 | Time(s) 2.1933
# Epoch 00107 | Loss 0.2114 | Train.Rand 0.8862 | Valid.Rand 0.5100 | Time(s) 2.1922
# Epoch 00108 | Loss 0.2410 | Train.Rand 0.8862 | Valid.Rand 0.5255 | Time(s) 2.1911
# Epoch 00109 | Loss 0.2067 | Train.Rand 0.8862 | Valid.Rand 0.5023 | Time(s) 2.1923
# Epoch 00110 | Loss 0.2103 | Train.Rand 0.8827 | Valid.Rand 0.4927 | Time(s) 2.1924
# Epoch 00111 | Loss 0.1977 | Train.Rand 0.8827 | Valid.Rand 0.4897 | Time(s) 2.1913
# Epoch 00112 | Loss 0.2015 | Train.Rand 0.8693 | Valid.Rand 0.4853 | Time(s) 2.1906
# Epoch 00113 | Loss 0.2094 | Train.Rand 0.8986 | Valid.Rand 0.5195 | Time(s) 2.1899
# Epoch 00114 | Loss 0.2364 | Train.Rand 0.8846 | Valid.Rand 0.5195 | Time(s) 2.1893
# Epoch 00115 | Loss 0.1963 | Train.Rand 0.8905 | Valid.Rand 0.4856 | Time(s) 2.1890
# Epoch 00116 | Loss 0.2178 | Train.Rand 0.9095 | Valid.Rand 0.4980 | Time(s) 2.1901
# Epoch 00117 | Loss 0.2270 | Train.Rand 0.9095 | Valid.Rand 0.4959 | Time(s) 2.1900
# Epoch 00118 | Loss 0.2152 | Train.Rand 0.9105 | Valid.Rand 0.4741 | Time(s) 2.1909
# Epoch 00119 | Loss 0.2215 | Train.Rand 0.9095 | Valid.Rand 0.4530 | Time(s) 2.1896
# Epoch 00120 | Loss 0.2153 | Train.Rand 0.9046 | Valid.Rand 0.4723 | Time(s) 2.1887
# Epoch 00121 | Loss 0.1985 | Train.Rand 0.9480 | Valid.Rand 0.4859 | Time(s) 2.1876
# Epoch 00122 | Loss 0.1951 | Train.Rand 0.9347 | Valid.Rand 0.4752 | Time(s) 2.1874
# Epoch 00123 | Loss 0.2058 | Train.Rand 0.9278 | Valid.Rand 0.4842 | Time(s) 2.1871
# Epoch 00124 | Loss 0.1941 | Train.Rand 0.9456 | Valid.Rand 0.5043 | Time(s) 2.1863
# Epoch 00125 | Loss 0.2037 | Train.Rand 0.9381 | Valid.Rand 0.5064 | Time(s) 2.1863
# Epoch 00126 | Loss 0.2032 | Train.Rand 0.9188 | Valid.Rand 0.4954 | Time(s) 2.1862
# Epoch 00127 | Loss 0.2342 | Train.Rand 0.9169 | Valid.Rand 0.4943 | Time(s) 2.1863
# Epoch 00128 | Loss 0.2131 | Train.Rand 0.9061 | Valid.Rand 0.5076 | Time(s) 2.1874
# Epoch 00129 | Loss 0.2242 | Train.Rand 0.8976 | Valid.Rand 0.4910 | Time(s) 2.1871
# Epoch 00130 | Loss 0.2410 | Train.Rand 0.9077 | Valid.Rand 0.4795 | Time(s) 2.1880
# Epoch 00131 | Loss 0.1987 | Train.Rand 0.8966 | Valid.Rand 0.4909 | Time(s) 2.1883
# Epoch 00132 | Loss 0.2866 | Train.Rand 0.8901 | Valid.Rand 0.5228 | Time(s) 2.1872
# Epoch 00133 | Loss 0.2014 | Train.Rand 0.9115 | Valid.Rand 0.4979 | Time(s) 2.1870
# Epoch 00134 | Loss 0.1933 | Train.Rand 0.9115 | Valid.Rand 0.4874 | Time(s) 2.1881
# Epoch 00135 | Loss 0.2078 | Train.Rand 0.8971 | Valid.Rand 0.4984 | Time(s) 2.1872
# Epoch 00136 | Loss 0.2487 | Train.Rand 0.8678 | Valid.Rand 0.4801 | Time(s) 2.1861
# Epoch 00137 | Loss 0.2052 | Train.Rand 0.9083 | Valid.Rand 0.4932 | Time(s) 2.1856
# Epoch 00138 | Loss 0.1801 | Train.Rand 0.9293 | Valid.Rand 0.4887 | Time(s) 2.1865
# Epoch 00139 | Loss 0.1772 | Train.Rand 0.9519 | Valid.Rand 0.5063 | Time(s) 2.1865
# Epoch 00140 | Loss 0.2066 | Train.Rand 0.9382 | Valid.Rand 0.5045 | Time(s) 2.1857
# Epoch 00141 | Loss 0.1961 | Train.Rand 0.9353 | Valid.Rand 0.4969 | Time(s) 2.1845
# Epoch 00142 | Loss 0.1886 | Train.Rand 0.9387 | Valid.Rand 0.5088 | Time(s) 2.1844
# Epoch 00143 | Loss 0.1930 | Train.Rand 0.9519 | Valid.Rand 0.4928 | Time(s) 2.1838
# Epoch 00144 | Loss 0.2017 | Train.Rand 0.9338 | Valid.Rand 0.5025 | Time(s) 2.1838
# Epoch 00145 | Loss 0.1850 | Train.Rand 0.9255 | Valid.Rand 0.4946 | Time(s) 2.1838
# Epoch 00146 | Loss 0.1745 | Train.Rand 0.9255 | Valid.Rand 0.4949 | Time(s) 2.1846
# Epoch 00147 | Loss 0.2084 | Train.Rand 0.9189 | Valid.Rand 0.4761 | Time(s) 2.1838
# Epoch 00148 | Loss 0.1971 | Train.Rand 0.8925 | Valid.Rand 0.4692 | Time(s) 2.1837
# Epoch 00149 | Loss 0.2128 | Train.Rand 0.8980 | Valid.Rand 0.4766 | Time(s) 2.1829
# Epoch 00150 | Loss 0.1679 | Train.Rand 0.9405 | Valid.Rand 0.4963 | Time(s) 2.1826
# Epoch 00151 | Loss 0.1806 | Train.Rand 0.9374 | Valid.Rand 0.4575 | Time(s) 2.1839
# Epoch 00152 | Loss 0.2444 | Train.Rand 0.9366 | Valid.Rand 0.4805 | Time(s) 2.1830
# Epoch 00153 | Loss 0.1637 | Train.Rand 0.9550 | Valid.Rand 0.4979 | Time(s) 2.1839
# Epoch 00154 | Loss 0.2149 | Train.Rand 0.9139 | Valid.Rand 0.5123 | Time(s) 2.1851
# Epoch 00155 | Loss 0.2250 | Train.Rand 0.9081 | Valid.Rand 0.4957 | Time(s) 2.1862
# Epoch 00156 | Loss 0.1893 | Train.Rand 0.9293 | Valid.Rand 0.4734 | Time(s) 2.1867
# Epoch 00157 | Loss 0.1933 | Train.Rand 0.9405 | Valid.Rand 0.4799 | Time(s) 2.1868
# Epoch 00158 | Loss 0.1941 | Train.Rand 0.9447 | Valid.Rand 0.4816 | Time(s) 2.1866
# Epoch 00159 | Loss 0.1975 | Train.Rand 0.9397 | Valid.Rand 0.5025 | Time(s) 2.1869
# Epoch 00160 | Loss 0.1918 | Train.Rand 0.9540 | Valid.Rand 0.5032 | Time(s) 2.1861
# Epoch 00161 | Loss 0.1822 | Train.Rand 0.9625 | Valid.Rand 0.5287 | Time(s) 2.1866
# Epoch 00162 | Loss 0.1667 | Train.Rand 0.9310 | Valid.Rand 0.5052 | Time(s) 2.1869
# Epoch 00163 | Loss 0.1870 | Train.Rand 0.9042 | Valid.Rand 0.4959 | Time(s) 2.1862
# Epoch 00164 | Loss 0.1663 | Train.Rand 0.9220 | Valid.Rand 0.4785 | Time(s) 2.1865
# Epoch 00165 | Loss 0.2009 | Train.Rand 0.9114 | Valid.Rand 0.4977 | Time(s) 2.1858
# Epoch 00166 | Loss 0.1833 | Train.Rand 0.9221 | Valid.Rand 0.5036 | Time(s) 2.1871
# Epoch 00167 | Loss 0.1965 | Train.Rand 0.9472 | Valid.Rand 0.4757 | Time(s) 2.1872
# Epoch 00168 | Loss 0.1599 | Train.Rand 0.9625 | Valid.Rand 0.4736 | Time(s) 2.1870
# Epoch 00169 | Loss 0.1847 | Train.Rand 0.9478 | Valid.Rand 0.4725 | Time(s) 2.1874
# Epoch 00170 | Loss 0.1888 | Train.Rand 0.9365 | Valid.Rand 0.4815 | Time(s) 2.1874
# Epoch 00171 | Loss 0.1731 | Train.Rand 0.9436 | Valid.Rand 0.4828 | Time(s) 2.1872
# Epoch 00172 | Loss 0.1539 | Train.Rand 0.9625 | Valid.Rand 0.4587 | Time(s) 2.1867
# Epoch 00173 | Loss 0.1796 | Train.Rand 0.9553 | Valid.Rand 0.4740 | Time(s) 2.1874
# Epoch 00174 | Loss 0.1778 | Train.Rand 0.9553 | Valid.Rand 0.4517 | Time(s) 2.1884
# Epoch 00175 | Loss 0.1635 | Train.Rand 0.9625 | Valid.Rand 0.4557 | Time(s) 2.1891
# Epoch 00176 | Loss 0.1647 | Train.Rand 0.9519 | Valid.Rand 0.4594 | Time(s) 2.1895
# Epoch 00177 | Loss 0.1729 | Train.Rand 0.9293 | Valid.Rand 0.4549 | Time(s) 2.1888
# Epoch 00178 | Loss 0.1630 | Train.Rand 0.9293 | Valid.Rand 0.4888 | Time(s) 2.1882
# Epoch 00179 | Loss 0.1769 | Train.Rand 0.9316 | Valid.Rand 0.4752 | Time(s) 2.1879
# Epoch 00180 | Loss 0.1664 | Train.Rand 0.9330 | Valid.Rand 0.4890 | Time(s) 2.1885
# Epoch 00181 | Loss 0.1432 | Train.Rand 0.9314 | Valid.Rand 0.5021 | Time(s) 2.1893
# Epoch 00182 | Loss 0.1614 | Train.Rand 0.9400 | Valid.Rand 0.5122 | Time(s) 2.1885
# Epoch 00183 | Loss 0.2115 | Train.Rand 0.8992 | Valid.Rand 0.4941 | Time(s) 2.1888
# Epoch 00184 | Loss 0.1738 | Train.Rand 0.9625 | Valid.Rand 0.4819 | Time(s) 2.1899
# Epoch 00185 | Loss 0.1880 | Train.Rand 0.9426 | Valid.Rand 0.4763 | Time(s) 2.1907
# Epoch 00186 | Loss 0.2604 | Train.Rand 0.8833 | Valid.Rand 0.4374 | Time(s) 2.1901
# Epoch 00187 | Loss 0.1561 | Train.Rand 0.9526 | Valid.Rand 0.4903 | Time(s) 2.1896
# Epoch 00188 | Loss 0.1700 | Train.Rand 0.9586 | Valid.Rand 0.4629 | Time(s) 2.1904
# Epoch 00189 | Loss 0.1761 | Train.Rand 0.9595 | Valid.Rand 0.4676 | Time(s) 2.1900
# Epoch 00190 | Loss 0.1643 | Train.Rand 0.9569 | Valid.Rand 0.4849 | Time(s) 2.1907
# Epoch 00191 | Loss 0.1761 | Train.Rand 0.9540 | Valid.Rand 0.4793 | Time(s) 2.1907
# Epoch 00192 | Loss 0.1656 | Train.Rand 0.9394 | Valid.Rand 0.4796 | Time(s) 2.1916
# Epoch 00193 | Loss 0.1636 | Train.Rand 0.9345 | Valid.Rand 0.5098 | Time(s) 2.1911
# Epoch 00194 | Loss 0.1679 | Train.Rand 0.9416 | Valid.Rand 0.4973 | Time(s) 2.1912
# Epoch 00195 | Loss 0.1557 | Train.Rand 0.9400 | Valid.Rand 0.5065 | Time(s) 2.1913
# Epoch 00196 | Loss 0.1587 | Train.Rand 0.9185 | Valid.Rand 0.4985 | Time(s) 2.1918
# Epoch 00197 | Loss 0.1636 | Train.Rand 0.9058 | Valid.Rand 0.4822 | Time(s) 2.1918
# Epoch 00198 | Loss 0.1759 | Train.Rand 0.9185 | Valid.Rand 0.4936 | Time(s) 2.1926
# Epoch 00199 | Loss 0.1603 | Train.Rand 0.9291 | Valid.Rand 0.4962 | Time(s) 2.1927
# Epoch 00200 | Loss 0.1586 | Train.Rand 0.9334 | Valid.Rand 0.4932 | Time(s) 2.1926
# Epoch 00201 | Loss 0.1740 | Train.Rand 0.9377 | Valid.Rand 0.4964 | Time(s) 2.1920
# Epoch 00202 | Loss 0.1750 | Train.Rand 0.9555 | Valid.Rand 0.5377 | Time(s) 2.1921
# Epoch 00203 | Loss 0.1859 | Train.Rand 0.9540 | Valid.Rand 0.5239 | Time(s) 2.1919
# Epoch 00204 | Loss 0.1603 | Train.Rand 0.9586 | Valid.Rand 0.4886 | Time(s) 2.1914
# Epoch 00205 | Loss 0.1744 | Train.Rand 0.9279 | Valid.Rand 0.4974 | Time(s) 2.1909
# Epoch 00206 | Loss 0.1480 | Train.Rand 0.9557 | Valid.Rand 0.4804 | Time(s) 2.1907
# Epoch 00207 | Loss 0.1612 | Train.Rand 0.9625 | Valid.Rand 0.4986 | Time(s) 2.1913
# Epoch 00208 | Loss 0.1683 | Train.Rand 0.9625 | Valid.Rand 0.4708 | Time(s) 2.1906
# Epoch 00209 | Loss 0.1379 | Train.Rand 0.9621 | Valid.Rand 0.4795 | Time(s) 2.1915
# Epoch 00210 | Loss 0.1675 | Train.Rand 0.9583 | Valid.Rand 0.4855 | Time(s) 2.1920
# Epoch 00211 | Loss 0.1801 | Train.Rand 0.9661 | Valid.Rand 0.4668 | Time(s) 2.1931
# Epoch 00212 | Loss 0.1702 | Train.Rand 0.9625 | Valid.Rand 0.4685 | Time(s) 2.1941
# Epoch 00213 | Loss 0.2036 | Train.Rand 0.9376 | Valid.Rand 0.4600 | Time(s) 2.1945
# Epoch 00214 | Loss 0.1594 | Train.Rand 0.9205 | Valid.Rand 0.4602 | Time(s) 2.1938
# Epoch 00215 | Loss 0.2137 | Train.Rand 0.9295 | Valid.Rand 0.4590 | Time(s) 2.1940
# Epoch 00216 | Loss 0.2831 | Train.Rand 0.9142 | Valid.Rand 0.4641 | Time(s) 2.1935
# Epoch 00217 | Loss 0.1849 | Train.Rand 0.9540 | Valid.Rand 0.4971 | Time(s) 2.1933
# Epoch 00218 | Loss 0.3027 | Train.Rand 0.9227 | Valid.Rand 0.4998 | Time(s) 2.1928
# Epoch 00219 | Loss 0.2858 | Train.Rand 0.9237 | Valid.Rand 0.4803 | Time(s) 2.1940
# Epoch 00220 | Loss 0.2350 | Train.Rand 0.9395 | Valid.Rand 0.5282 | Time(s) 2.1939
# Epoch 00221 | Loss 0.5262 | Train.Rand 0.8439 | Valid.Rand 0.4659 | Time(s) 2.1933
# Epoch 00222 | Loss 0.8012 | Train.Rand 0.7288 | Valid.Rand 0.4075 | Time(s) 2.1931
# Epoch 00223 | Loss 0.3298 | Train.Rand 0.8929 | Valid.Rand 0.4868 | Time(s) 2.1933
# Epoch 00224 | Loss 0.4779 | Train.Rand 0.8337 | Valid.Rand 0.5059 | Time(s) 2.1928
# Epoch 00225 | Loss 0.5348 | Train.Rand 0.8315 | Valid.Rand 0.4846 | Time(s) 2.1926
# Epoch 00226 | Loss 0.3380 | Train.Rand 0.8642 | Valid.Rand 0.5140 | Time(s) 2.1925
# Epoch 00227 | Loss 0.2859 | Train.Rand 0.9018 | Valid.Rand 0.4945 | Time(s) 2.1925
# Epoch 00228 | Loss 0.3241 | Train.Rand 0.9133 | Valid.Rand 0.5059 | Time(s) 2.1921
# Epoch 00229 | Loss 0.2474 | Train.Rand 0.9036 | Valid.Rand 0.5175 | Time(s) 2.1913
# Epoch 00230 | Loss 0.3012 | Train.Rand 0.8748 | Valid.Rand 0.5048 | Time(s) 2.1920
# Epoch 00231 | Loss 0.2113 | Train.Rand 0.9045 | Valid.Rand 0.5092 | Time(s) 2.1930
# Epoch 00232 | Loss 0.1860 | Train.Rand 0.9470 | Valid.Rand 0.4715 | Time(s) 2.1927
# Epoch 00233 | Loss 0.2637 | Train.Rand 0.9568 | Valid.Rand 0.4858 | Time(s) 2.1925
# Epoch 00234 | Loss 0.1803 | Train.Rand 0.9402 | Valid.Rand 0.4896 | Time(s) 2.1927
# Epoch 00235 | Loss 0.1572 | Train.Rand 0.9450 | Valid.Rand 0.4562 | Time(s) 2.1923
# Epoch 00236 | Loss 0.1614 | Train.Rand 0.9637 | Valid.Rand 0.4615 | Time(s) 2.1921
# Epoch 00237 | Loss 0.2049 | Train.Rand 0.9319 | Valid.Rand 0.4706 | Time(s) 2.1914
# Epoch 00238 | Loss 0.1683 | Train.Rand 0.9612 | Valid.Rand 0.4623 | Time(s) 2.1909
# Epoch 00239 | Loss 0.1633 | Train.Rand 0.9657 | Valid.Rand 0.4658 | Time(s) 2.1913
# Epoch 00240 | Loss 0.1431 | Train.Rand 0.9657 | Valid.Rand 0.4635 | Time(s) 2.1910
# Epoch 00241 | Loss 0.1664 | Train.Rand 0.9713 | Valid.Rand 0.4923 | Time(s) 2.1905
# Epoch 00242 | Loss 0.1389 | Train.Rand 0.9660 | Valid.Rand 0.5005 | Time(s) 2.1900
# Epoch 00243 | Loss 0.1920 | Train.Rand 0.9713 | Valid.Rand 0.5151 | Time(s) 2.1897
# Epoch 00244 | Loss 0.1579 | Train.Rand 0.9713 | Valid.Rand 0.5125 | Time(s) 2.1896
# Epoch 00245 | Loss 0.1519 | Train.Rand 0.9713 | Valid.Rand 0.5011 | Time(s) 2.1891
# Epoch 00246 | Loss 0.1420 | Train.Rand 0.9672 | Valid.Rand 0.5088 | Time(s) 2.1886
# Epoch 00247 | Loss 0.1555 | Train.Rand 0.9625 | Valid.Rand 0.5081 | Time(s) 2.1896
# Epoch 00248 | Loss 0.1251 | Train.Rand 0.9625 | Valid.Rand 0.5072 | Time(s) 2.1889
# Epoch 00249 | Loss 0.1302 | Train.Rand 0.9625 | Valid.Rand 0.4895 | Time(s) 2.1890
# Epoch 00250 | Loss 0.1352 | Train.Rand 0.9625 | Valid.Rand 0.4888 | Time(s) 2.1883
# Epoch 00251 | Loss 0.1399 | Train.Rand 0.9625 | Valid.Rand 0.4892 | Time(s) 2.1882
# Epoch 00252 | Loss 0.1372 | Train.Rand 0.9625 | Valid.Rand 0.4979 | Time(s) 2.1879
# Epoch 00253 | Loss 0.1768 | Train.Rand 0.9661 | Valid.Rand 0.4931 | Time(s) 2.1876
# Epoch 00254 | Loss 0.1317 | Train.Rand 0.9661 | Valid.Rand 0.4967 | Time(s) 2.1873
# Epoch 00255 | Loss 0.1462 | Train.Rand 0.9574 | Valid.Rand 0.4874 | Time(s) 2.1876
# Epoch 00256 | Loss 0.1585 | Train.Rand 0.9625 | Valid.Rand 0.4838 | Time(s) 2.1870
# Epoch 00257 | Loss 0.1434 | Train.Rand 0.9625 | Valid.Rand 0.4830 | Time(s) 2.1866
# Epoch 00258 | Loss 0.1683 | Train.Rand 0.9713 | Valid.Rand 0.4846 | Time(s) 2.1871
# Epoch 00259 | Loss 0.1521 | Train.Rand 0.9599 | Valid.Rand 0.4907 | Time(s) 2.1877
# Epoch 00260 | Loss 0.1422 | Train.Rand 0.9599 | Valid.Rand 0.4907 | Time(s) 2.1884
# Epoch 00261 | Loss 0.1286 | Train.Rand 0.9426 | Valid.Rand 0.5070 | Time(s) 2.1877
# Epoch 00262 | Loss 0.1306 | Train.Rand 0.9511 | Valid.Rand 0.5148 | Time(s) 2.1873
# Epoch 00263 | Loss 0.1847 | Train.Rand 0.9625 | Valid.Rand 0.5014 | Time(s) 2.1870
# Epoch 00264 | Loss 0.1497 | Train.Rand 0.9713 | Valid.Rand 0.4990 | Time(s) 2.1872
# Epoch 00265 | Loss 0.1380 | Train.Rand 0.9713 | Valid.Rand 0.4876 | Time(s) 2.1867
# Epoch 00266 | Loss 0.1515 | Train.Rand 0.9713 | Valid.Rand 0.4914 | Time(s) 2.1872
# Epoch 00267 | Loss 0.1421 | Train.Rand 0.9511 | Valid.Rand 0.4829 | Time(s) 2.1878
# Epoch 00268 | Loss 0.1796 | Train.Rand 0.9083 | Valid.Rand 0.4770 | Time(s) 2.1873
# Epoch 00269 | Loss 0.1502 | Train.Rand 0.9713 | Valid.Rand 0.5005 | Time(s) 2.1868
# Epoch 00270 | Loss 0.1810 | Train.Rand 0.9623 | Valid.Rand 0.4878 | Time(s) 2.1868
# Epoch 00271 | Loss 0.1281 | Train.Rand 0.9713 | Valid.Rand 0.4934 | Time(s) 2.1868
# Epoch 00272 | Loss 0.1528 | Train.Rand 0.9663 | Valid.Rand 0.5312 | Time(s) 2.1867
# Epoch 00273 | Loss 0.1369 | Train.Rand 0.9503 | Valid.Rand 0.5243 | Time(s) 2.1863
# Epoch 00274 | Loss 0.1328 | Train.Rand 0.9599 | Valid.Rand 0.5196 | Time(s) 2.1862
# Epoch 00275 | Loss 0.1303 | Train.Rand 0.9599 | Valid.Rand 0.5124 | Time(s) 2.1865
# Epoch 00276 | Loss 0.1584 | Train.Rand 0.9672 | Valid.Rand 0.5112 | Time(s) 2.1862
# Epoch 00277 | Loss 0.1427 | Train.Rand 0.9713 | Valid.Rand 0.4892 | Time(s) 2.1869
# Epoch 00278 | Loss 0.1392 | Train.Rand 0.9713 | Valid.Rand 0.5102 | Time(s) 2.1864
# Epoch 00279 | Loss 0.1354 | Train.Rand 0.9511 | Valid.Rand 0.5096 | Time(s) 2.1868
# Epoch 00280 | Loss 0.1513 | Train.Rand 0.9511 | Valid.Rand 0.4971 | Time(s) 2.1865
# Epoch 00281 | Loss 0.1668 | Train.Rand 0.9713 | Valid.Rand 0.4968 | Time(s) 2.1863
# Epoch 00282 | Loss 0.1493 | Train.Rand 0.9713 | Valid.Rand 0.5014 | Time(s) 2.1858
# Epoch 00283 | Loss 0.1446 | Train.Rand 0.9713 | Valid.Rand 0.5081 | Time(s) 2.1859
# Epoch 00284 | Loss 0.1647 | Train.Rand 0.9611 | Valid.Rand 0.4902 | Time(s) 2.1859
# Epoch 00285 | Loss 0.1357 | Train.Rand 0.9661 | Valid.Rand 0.4965 | Time(s) 2.1864
# Epoch 00286 | Loss 0.1435 | Train.Rand 0.9625 | Valid.Rand 0.4948 | Time(s) 2.1859
# Epoch 00287 | Loss 0.1416 | Train.Rand 0.9625 | Valid.Rand 0.4909 | Time(s) 2.1858
# Epoch 00288 | Loss 0.1181 | Train.Rand 0.9625 | Valid.Rand 0.4909 | Time(s) 2.1856
# Epoch 00289 | Loss 0.1166 | Train.Rand 0.9625 | Valid.Rand 0.4942 | Time(s) 2.1861
# Epoch 00290 | Loss 0.1241 | Train.Rand 0.9511 | Valid.Rand 0.4931 | Time(s) 2.1859
# Epoch 00291 | Loss 0.1476 | Train.Rand 0.9547 | Valid.Rand 0.4897 | Time(s) 2.1861
# Epoch 00292 | Loss 0.1535 | Train.Rand 0.9713 | Valid.Rand 0.4822 | Time(s) 2.1863
# Epoch 00293 | Loss 0.1326 | Train.Rand 0.9713 | Valid.Rand 0.4754 | Time(s) 2.1858
# Epoch 00294 | Loss 0.1480 | Train.Rand 0.9713 | Valid.Rand 0.4804 | Time(s) 2.1858
# Epoch 00295 | Loss 0.1281 | Train.Rand 0.9713 | Valid.Rand 0.4872 | Time(s) 2.1857
# Epoch 00296 | Loss 0.1199 | Train.Rand 0.9713 | Valid.Rand 0.4861 | Time(s) 2.1861
# Epoch 00297 | Loss 0.1484 | Train.Rand 0.9642 | Valid.Rand 0.4893 | Time(s) 2.1857
# Epoch 00298 | Loss 0.1573 | Train.Rand 0.9481 | Valid.Rand 0.4928 | Time(s) 2.1859
# Epoch 00299 | Loss 0.1406 | Train.Rand 0.9713 | Valid.Rand 0.4798 | Time(s) 2.1860
# Epoch 00300 | Loss 0.1567 | Train.Rand 0.9625 | Valid.Rand 0.4948 | Time(s) 2.1859
# Epoch 00301 | Loss 0.1643 | Train.Rand 0.9228 | Valid.Rand 0.4766 | Time(s) 2.1861
# Epoch 00302 | Loss 0.2082 | Train.Rand 0.9148 | Valid.Rand 0.4741 | Time(s) 2.1856
# Epoch 00303 | Loss 0.1319 | Train.Rand 0.9625 | Valid.Rand 0.4969 | Time(s) 2.1859
# Epoch 00304 | Loss 0.1410 | Train.Rand 0.9550 | Valid.Rand 0.4803 | Time(s) 2.1858
# Epoch 00305 | Loss 0.1753 | Train.Rand 0.9103 | Valid.Rand 0.4755 | Time(s) 2.1857
# Epoch 00306 | Loss 0.1439 | Train.Rand 0.9642 | Valid.Rand 0.4806 | Time(s) 2.1864
# Epoch 00307 | Loss 0.2178 | Train.Rand 0.9435 | Valid.Rand 0.4726 | Time(s) 2.1859
# Epoch 00308 | Loss 0.1442 | Train.Rand 0.9550 | Valid.Rand 0.4689 | Time(s) 2.1862
# Epoch 00309 | Loss 0.1292 | Train.Rand 0.9625 | Valid.Rand 0.4606 | Time(s) 2.1865
# Epoch 00310 | Loss 0.1475 | Train.Rand 0.9661 | Valid.Rand 0.4750 | Time(s) 2.1867
# Epoch 00311 | Loss 0.1499 | Train.Rand 0.9661 | Valid.Rand 0.4912 | Time(s) 2.1862
# Epoch 00312 | Loss 0.1258 | Train.Rand 0.9611 | Valid.Rand 0.4931 | Time(s) 2.1861
# Epoch 00313 | Loss 0.1275 | Train.Rand 0.9592 | Valid.Rand 0.5098 | Time(s) 2.1856
# Epoch 00314 | Loss 0.1263 | Train.Rand 0.9661 | Valid.Rand 0.5148 | Time(s) 2.1858
# Epoch 00315 | Loss 0.1183 | Train.Rand 0.9625 | Valid.Rand 0.5144 | Time(s) 2.1854
# Epoch 00316 | Loss 0.1260 | Train.Rand 0.9511 | Valid.Rand 0.4987 | Time(s) 2.1853
# Epoch 00317 | Loss 0.1267 | Train.Rand 0.9400 | Valid.Rand 0.5021 | Time(s) 2.1849
# Epoch 00318 | Loss 0.1257 | Train.Rand 0.9400 | Valid.Rand 0.5021 | Time(s) 2.1846
# Epoch 00319 | Loss 0.1249 | Train.Rand 0.9625 | Valid.Rand 0.4940 | Time(s) 2.1842
# Epoch 00320 | Loss 0.1215 | Train.Rand 0.9713 | Valid.Rand 0.4963 | Time(s) 2.1839
# Epoch 00321 | Loss 0.1310 | Train.Rand 0.9713 | Valid.Rand 0.4778 | Time(s) 2.1835
# Epoch 00322 | Loss 0.1329 | Train.Rand 0.9642 | Valid.Rand 0.4734 | Time(s) 2.1831
# Epoch 00323 | Loss 0.1236 | Train.Rand 0.9713 | Valid.Rand 0.4750 | Time(s) 2.1836
# Epoch 00324 | Loss 0.1558 | Train.Rand 0.9713 | Valid.Rand 0.4743 | Time(s) 2.1844
# Epoch 00325 | Loss 0.1110 | Train.Rand 0.9625 | Valid.Rand 0.4928 | Time(s) 2.1840
# Epoch 00326 | Loss 0.1196 | Train.Rand 0.9625 | Valid.Rand 0.4819 | Time(s) 2.1842
# Epoch 00327 | Loss 0.1651 | Train.Rand 0.9625 | Valid.Rand 0.4742 | Time(s) 2.1845
# Epoch 00328 | Loss 0.1303 | Train.Rand 0.9713 | Valid.Rand 0.4777 | Time(s) 2.1847
# Epoch 00329 | Loss 0.1589 | Train.Rand 0.9332 | Valid.Rand 0.4657 | Time(s) 2.1845
# Epoch 00330 | Loss 0.1356 | Train.Rand 0.9713 | Valid.Rand 0.4868 | Time(s) 2.1842
# Epoch 00331 | Loss 0.1414 | Train.Rand 0.9713 | Valid.Rand 0.4885 | Time(s) 2.1841
# Epoch 00332 | Loss 0.1289 | Train.Rand 0.9511 | Valid.Rand 0.4747 | Time(s) 2.1849
# Epoch 00333 | Loss 0.1768 | Train.Rand 0.9426 | Valid.Rand 0.4820 | Time(s) 2.1844
# Epoch 00334 | Loss 0.1349 | Train.Rand 0.9713 | Valid.Rand 0.5067 | Time(s) 2.1850
# Epoch 00335 | Loss 0.1460 | Train.Rand 0.9584 | Valid.Rand 0.5015 | Time(s) 2.1851
# Epoch 00336 | Loss 0.1314 | Train.Rand 0.9584 | Valid.Rand 0.4945 | Time(s) 2.1854
# Epoch 00337 | Loss 0.1258 | Train.Rand 0.9661 | Valid.Rand 0.5006 | Time(s) 2.1860
# Epoch 00338 | Loss 0.1227 | Train.Rand 0.9625 | Valid.Rand 0.4880 | Time(s) 2.1857
# Epoch 00339 | Loss 0.1435 | Train.Rand 0.9625 | Valid.Rand 0.4869 | Time(s) 2.1858
# Epoch 00340 | Loss 0.1243 | Train.Rand 0.9625 | Valid.Rand 0.4797 | Time(s) 2.1856
# Epoch 00341 | Loss 0.1215 | Train.Rand 0.9511 | Valid.Rand 0.4866 | Time(s) 2.1852
# <All keys matched successfully>

# %%
import seaborn as sns
sns.lineplot(x=range(len(loss_ev)), y=loss_ev)

# %%
import performance as pf
import copy
loss_function = pf.perm_inv_loss(labels)

# %%
net.load_state_dict(current_best_params)
# Out:
# <All keys matched successfully>

# %%
# Visualise predictions
net.eval() # Set net to evaluation mode (deactivates dropout)
final_prediction = net(features).detach()
a = np.transpose(np.vstack([final_prediction[comb_mask].numpy().argmax(axis=1),labels[comb_mask].numpy()]))
a[a[:,0].argsort()][np.random.choice(range(a.shape[0]),size=10)]
# Out:
# array([[0, 5],
#        [3, 3],
#        [5, 2],
#        [1, 0],
#        [4, 6],
#        [4, 0],
#        [2, 1],
#        [6, 6],
#        [3, 3],
#        [5, 2]])

# %%
# Performnace evaluation functions

def variation_of_information_score(labels, preds):
    def mi(x, y):
        contingency = skmetrics.cluster.contingency_matrix(x, y, sparse=True)
        # print(contingency.todense())
        nzx, nzy, nz_val = sp.find(contingency)
        contingency_sum = contingency.sum()

        pi = np.ravel(contingency.sum(axis=1))
        pj = np.ravel(contingency.sum(axis=0))
        # print(nz_val)
        log_contingency_nm = np.log(nz_val)
        # print(log_contingency_nm)
        contingency_nm = nz_val / contingency_sum
        # print(contingency_nm)

        # Don't need to calculate the full outer product, just for non-zeroes
        outer = pi.take(nzx).astype(np.int64, copy=False) * pj.take(nzy).astype(
            np.int64, copy=False
        )
        # print(outer)
        log_outer = -np.log(outer) + log(pi.sum()) + log(pj.sum())
        # print(log_outer)
        mi = (
            contingency_nm * (log_contingency_nm - log(contingency_sum))
            + contingency_nm * log_outer
        )
        # print(mi)
        return mi.sum()

    return mi(labels, labels) + mi(preds, preds) - 2 * mi(labels, preds)


def mutual_info_score(labels, preds):
    return skmetrics.adjusted_mutual_info_score(labels, preds, average_method="arithmetic")

def compute_performance(labels, logits, splits):
    logits = logits.detach().numpy()
    preds = np.argmax(logits, axis=1)
    labels = labels.numpy()
    pred_sets = {
        "All ": preds,
        "Train": preds[mask_train],
        "Val": preds[mask_val],
        "Test": preds[test_mask],
    }
    label_sets = {
        "All ": labels,
        "Train": labels[mask_train],
        "Val": labels[mask_val],
        "Test": labels[test_mask],
    }
    eval_functions = {
        "Rand-Index": rand_score,
        "Mutual Information": mutual_info_score,
        "Variation of Information": variation_of_information_score,
    }
    scores = {
        subset: {
            name: func(label_sets[subset], pred_sets[subset])
            for name, func in eval_functions.items()
        }
        for subset in pred_sets.keys()
    }
    return scores

def performance_as_df(labels, logits, splits):
    scores = compute_performance(labels, logits, splits)
    return pd.DataFrame(scores)

def rand_score(labels, preds):
    return skmetrics.adjusted_rand_score(labels, preds)

# %%
net.eval() # Set net to evaluation mode (deactivates dropout)
final_prediction = net(features).detach()
performance_as_df(labels,final_prediction,comb_mask)
# Out:
#                               All      Train       Val      Test
# Rand-Index                0.558294  0.971305  0.492320  0.554135
# Mutual Information        0.532625  0.969968  0.495712  0.532490
# Variation of Information  1.691030  0.105132  1.753864  1.678290
